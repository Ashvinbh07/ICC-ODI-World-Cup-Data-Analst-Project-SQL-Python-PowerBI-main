# %%
import pandas as pd

# %%
#Loading Data
matches = pd.read_csv("raw_data/Match Dataset.csv")
deliveries = pd.read_csv("raw_data/Ball_by_Ball Dataset.csv")

# %%
print(matches.info())
print()
print(deliveries.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      241 non-null    int64
#  1   match_id        241 non-null    int64
#  2   date            241 non-null    str
#  3   venue           241 non-null    str
#  4   city            241 non-null    str
#  5   team1           241 non-null    str
#  6   team2           241 non-null    str
#  7   toss_winner     241 non-null    int64
#  8   toss_decision   241 non-null    str
#  9   winner          241 non-null    int64
#  10  team1_player1   241 non-null    str
#  11  team2_player1   241 non-null    str
#  12  team1_player2   241 non-null    str
#  13  team2_player2   241 non-null    str
#  14  team1_player3   241 non-null    str
#  15  team2_player3   241 non-null    str
#  16  team1_player4   241 non-null    str
#  17  team2_player4   241 non-null    str
# ...

# %%
print(matches.describe())
print()
print(deliveries.describe())
# Out:
#        Unnamed: 0     match_id  toss_winner     winner
# count  241.000000   241.000000   241.000000  241.00000
# mean   120.000000  3247.004149     0.510373    0.40249
# std     69.714896   940.885622     0.500933    0.49142
# min      0.000000  1942.000000     0.000000    0.00000
# 25%     60.000000  2547.000000     0.000000    0.00000
# 50%    120.000000  3129.000000     1.000000    0.00000
# 75%    180.000000  4159.000000     1.000000    1.00000
# max    240.000000  4705.000000     1.000000    1.00000
#
#           Unnamed: 0       match_id         inning           over  \
# count  129397.000000  129397.000000  129397.000000  129397.000000
# mean    64698.000000    3264.159540       1.484007      22.240647
# std     37353.840728     940.437417       0.499746      13.857640
# min         0.000000    1942.000000       1.000000       0.000000
# 25%     32349.000000    2547.000000       1.000000      10.000000
# 50%     64698.000000    3131.000000       1.000000      21.000000
# ...

# %%
print(matches.isnull().sum())
print()
print(deliveries.isnull().sum())
# Out:
# Unnamed: 0        0
# match_id          0
# date              0
# venue             0
# city              0
# team1             0
# team2             0
# toss_winner       0
# toss_decision     0
# winner            0
# team1_player1     0
# team2_player1     0
# team1_player2     0
# team2_player2     0
# team1_player3     0
# team2_player3     0
# team1_player4     0
# team2_player4     0
# team1_player5     0
# team2_player5     0
# team1_player6     0
# team2_player6     0
# team1_player7     0
# team2_player7     0
# team1_player8     0
# team2_player8     0
# team1_player9     0
# team2_player9     0
# team1_player10    0
# team2_player10    0
# team1_player11    0
# team2_player11    0
# dtype: int64
#
# Unnamed: 0                0
# match_id                  0
# inning                    0
# batting_team              0
# bowling_team              0
# over                      0
# ball_in_over              0
# batter                    0
# bowler                    0
# ...

# %%
print(matches.shape)
print()
print(deliveries.shape)
# Out:
# (241, 32)
#
# (129397, 28)
